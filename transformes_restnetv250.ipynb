# %%
import zipfile
import os
from google.colab import drive

# Authenticate and mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model
from tensorflow.keras.applications import ResNet50V2
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MeanSquaredError
import pandas as pd
import os

# GPU memory management (for low GPU memory)
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_virtual_device_configuration(gpu,
                [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=4096)])
    except RuntimeError as e:
        print(e)

# Directories
hazy_image_dir = '/content/drive/MyDrive/Preprocessed_Hazy_Images'
clear_image_dir = '/content/drive/MyDrive/Preprocessed_Clear_Images'

# Image dimensions
IMG_HEIGHT, IMG_WIDTH = 128, 128

# Data Generator
datagen = ImageDataGenerator(rescale=1./255)

# Create list of file paths for hazy and clear images
hazy_images = [os.path.join(hazy_image_dir, fname) for fname in os.listdir(hazy_image_dir) if fname.endswith('.tif')]
clear_images = [os.path.join(clear_image_dir, fname) for fname in os.listdir(clear_image_dir) if fname.endswith('.tif')]

# Create a dataframe
df = pd.DataFrame({
    'filename': hazy_images + clear_images,
    'label': ['hazy'] * len(hazy_images) + ['clear'] * len(clear_images)
})

# Create data generators
hazy_generator = datagen.flow_from_dataframe(
    dataframe=df[df['label'] == 'hazy'],
    x_col='filename',
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=4,
    class_mode=None,
    shuffle=False
)

clear_generator = datagen.flow_from_dataframe(
    dataframe=df[df['label'] == 'clear'],
    x_col='filename',
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=4,
    class_mode=None,
    shuffle=False
)

class TransformerBlock(layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1):
        super(TransformerBlock, self).__init__()
        self.att = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.ffn = tf.keras.Sequential([
            layers.Dense(ff_dim, activation="relu"),
            layers.Dense(embed_dim),
        ])
        self.layernorm1 = layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = layers.LayerNormalization(epsilon=1e-6)
        self.dropout1 = layers.Dropout(rate)
        self.dropout2 = layers.Dropout(rate)

class TransformerBlock(layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1, **kwargs): # Add **kwargs
        super(TransformerBlock, self).__init__(**kwargs) # Pass **kwargs to super
        self.att = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.ffn = tf.keras.Sequential([
            layers.Dense(ff_dim, activation="relu"),
            layers.Dense(embed_dim),
        ])
        self.layernorm1 = layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = layers.LayerNormalization(epsilon=1e-6)
        self.dropout1 = layers.Dropout(rate)
        self.dropout2 = layers.Dropout(rate)

    def call(self, inputs, training):
        attn_output = self.att(inputs, inputs)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(inputs + attn_output)
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        return self.layernorm2(out1 + ffn_output)

    def get_config(self):  # Add get_config method
        config = super(TransformerBlock, self).get_config()
        config.update({
            'embed_dim': self.att.key_dim,
            'num_heads': self.att.num_heads,
            'ff_dim': self.ffn.layers[0].units,  # Assuming ff_dim is the units of the first Dense layer in ffn
            'rate': self.dropout1.rate
        })
        return config


def dehazing_model(input_shape=(128, 128, 3), training=False):
    input_layer = layers.Input(shape=input_shape)

    # ResNet50V2 as the base model
    base_model = ResNet50V2(include_top=False, weights='imagenet', input_tensor=input_layer)
    base_model.trainable = False

    x = base_model.output  # Shape will be something like (4, 4, 2048)

    # Apply a Conv2D layer to reduce the number of channels
    x = layers.Conv2D(512, (1, 1), activation='relu')(x)

    # Transformer block after Conv2D
    x = TransformerBlock(512, 2, 128)(x, training=training)

    # Upsample to match the input size
    x = layers.Conv2DTranspose(256, 3, strides=2, padding='same', activation='relu')(x)  # 8x8
    x = TransformerBlock(256, 2, 64)(x, training=training)

    x = layers.Conv2DTranspose(128, 3, strides=2, padding='same', activation='relu')(x)  # 16x16
    x = TransformerBlock(128, 2, 32)(x, training=training)

    x = layers.Conv2DTranspose(64, 3, strides=2, padding='same', activation='relu')(x)  # 32x32
    x = TransformerBlock(64, 2, 16)(x, training=training)

    x = layers.Conv2DTranspose(32, 3, strides=2, padding='same', activation='relu')(x)  # 64x64
    x = TransformerBlock(32, 2, 16)(x, training=training)

    # Final upsampling to reach 128x128
    x = layers.Conv2DTranspose(16, 3, strides=2, padding='same', activation='relu')(x)  # 128x128

    # Output layer
    output = layers.Conv2D(3, 3, padding='same', activation='sigmoid')(x)  # Final output is 128x128x3

    model = Model(inputs=input_layer, outputs=output)
    return model



# Calculate the current shape of x dynamically
    current_shape = x.shape[1:]

    # Ensure the output matches the input shape
    x = layers.Reshape(target_shape=current_shape)(x)

    output = layers.Conv2D(3, 3, padding='same', activation='sigmoid')(x)

    model = Model(inputs=input_layer, outputs=output)
    return model

# Define metrics
def psnr(y_true, y_pred):
    return tf.image.psnr(y_true, y_pred, max_val=1.0)

def ssim_metric(y_true, y_pred):
    return tf.image.ssim(y_true, y_pred, max_val=1.0)

def accuracy(y_true, y_pred):
    # For image data, we can consider a pixel "correct" if it's within a certain threshold
    threshold = 0.1
    return tf.reduce_mean(tf.cast(tf.abs(y_true - y_pred) < threshold, tf.float32))

# Create and compile the model
model = dehazing_model()
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss=MeanSquaredError(),
              metrics=[psnr, ssim_metric, accuracy])

# Define a generator that yields pairs of hazy and clear images
def image_pair_generator(hazy_generator, clear_generator):
    while True:
        hazy_images = next(hazy_generator)
        clear_images = next(clear_generator)
        yield hazy_images, clear_images

# Train the model
BATCH_SIZE = 2
GRADIENT_ACCUMULATION_STEPS = 4

history = model.fit(
    image_pair_generator(hazy_generator, clear_generator),
    epochs=1500,
    steps_per_epoch=len(hazy_generator) // GRADIENT_ACCUMULATION_STEPS,
    validation_data=image_pair_generator(hazy_generator, clear_generator),
    validation_steps=len(clear_generator) // (2 * GRADIENT_ACCUMULATION_STEPS)
)

# Save the model
model.save('dehazing_model.h5')

# Plot training history
import matplotlib.pyplot as plt

metrics = ['loss', 'psnr', 'ssim_metric', 'accuracy']
fig, axs = plt.subplots(2, 2, figsize=(15, 15))

for i, metric in enumerate(metrics):
    ax = axs[i//2, i%2]
    ax.plot(history.history[metric], label=f'Training {metric}')
    ax.plot(history.history[f'val_{metric}'], label=f'Validation {metric}')
    ax.set_title(f'Model {metric.capitalize()}')
    ax.set_xlabel('Epoch')
    ax.set_ylabel(metric.capitalize())
    ax.legend()

plt.tight_layout()
plt.show()

# Evaluate the model on the test set
test_loss, test_psnr, test_ssim, test_accuracy = model.evaluate(
    image_pair_generator(hazy_generator, clear_generator),
    steps=len(clear_generator) // GRADIENT_ACCUMULATION_STEPS
)

print(f"Test Loss: {test_loss:.4f}")
print(f"Test PSNR: {test_psnr:.4f}")
print(f"Test SSIM: {test_ssim:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")

import tensorflow as tf
import numpy as np
import os
import random
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
from PIL import Image

# Load the trained model
model = load_model('dehazing_model.h5', custom_objects={
    'psnr': tf.image.psnr,
    'ssim_metric': tf.image.ssim,
    'accuracy': lambda y_true, y_pred: tf.reduce_mean(tf.cast(tf.abs(y_true - y_pred) < 0.1, tf.float32)),
    'TransformerBlock': TransformerBlock
})

# Set paths
hazy_dir = '/content/drive/MyDrive/Hazy_Images/Hazy_img'
clear_dir = '/content/drive/MyDrive/Clear_Images/Clear_imgs'

# Get list of image files
hazy_files = [f for f in os.listdir(hazy_dir) if f.endswith('.tif')]

# Select a random image
random_file = random.choice(hazy_files)
hazy_path = os.path.join(hazy_dir, random_file)
clear_path = os.path.join(clear_dir, random_file)  # Assuming clear images have the same filename

# Load and preprocess the images
def load_and_preprocess(image_path):
    img = load_img(image_path, target_size=(128, 128))
    img_array = img_to_array(img) / 255.0
    return img_array

hazy_image = load_and_preprocess(hazy_path)
clear_image = load_and_preprocess(clear_path)

# Dehaze the image
dehazed_image = model.predict(np.expand_dims(hazy_image, axis=0))[0]

# Calculate PSNR and SSIM
psnr = tf.image.psnr(clear_image, dehazed_image, max_val=1.0)
ssim = tf.image.ssim(clear_image, dehazed_image, max_val=1.0)

print(f"PSNR: {psnr.numpy():.4f}")
print(f"SSIM: {ssim.numpy():.4f}")

# Display images
plt.figure(figsize=(15, 5))
plt.subplot(131)
plt.imshow(hazy_image)
plt.title('Hazy Image')
plt.axis('off')

plt.subplot(132)
plt.imshow(dehazed_image)
plt.title('Dehazed Image')
plt.axis('off')

plt.subplot(133)
plt.imshow(clear_image)
plt.title('Clear Image')
plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Found 224 validated image filenames.
# Found 224 validated image filenames.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94668760/94668760 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 80s 2s/step - accuracy: 0.1588 - loss: 0.1103 - psnr: 9.6399 - ssim_metric: 0.0573 - val_accuracy: 0.1338 - val_loss: 0.1037 - val_psnr: 9.9579 - val_ssim_metric: 0.0823
# Epoch 2/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 24s 2s/step - accuracy: 0.1527 - loss: 0.0993 - psnr: 10.2350 - ssim_metric: 0.0890 - val_accuracy: 0.1856 - val_loss: 0.0825 - val_psnr: 11.1353 - val_ssim_metric: 0.1193
# Epoch 3/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 10s 731ms/step - accuracy: 0.2446 - loss: 0.0664 - psnr: 11.8699 - ssim_metric: 0.1109 - val_accuracy: 0.2084 - val_loss: 0.0643 - val_psnr: 11.9921 - val_ssim_metric: 0.1501
# Epoch 4/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - accuracy: 0.2377 - loss: 0.0664 - psnr: 11.8932 - ssim_metric: 0.1264 - val_accuracy: 0.1944 - val_loss: 0.0700 - val_psnr: 11.7874 - val_ssim_metric: 0.1483
# Epoch 5/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.2177 - loss: 0.0673 - psnr: 12.0212 - ssim_metric: 0.1463 - val_accuracy: 0.2662 - val_loss: 0.0543 - val_psnr: 12.7111 - val_ssim_metric: 0.1283
# Epoch 6/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.2242 - loss: 0.0560 - psnr: 12.5953 - ssim_metric: 0.1363 - val_accuracy: 0.2795 - val_loss: 0.0507 - val_psnr: 13.0556 - val_ssim_metric: 0.1467
# Epoch 7/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.2072 - loss: 0.0599 - psnr: 12.3780 - ssim_metric: 0.1464 - val_accuracy: 0.2401 - val_loss: 0.0564 - val_psnr: 12.8622 - val_ssim_metric: 0.1822
# Epoch 8/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 0.3181 - loss: 0.0408 - psnr: 13.9453 - ssim_metric: 0.1370 - val_accuracy: 0.2570 - val_loss: 0.0456 - val_psnr: 13.5599 - val_ssim_metric: 0.1742
# Epoch 9/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.3270 - loss: 0.0397 - psnr: 14.0749 - ssim_metric: 0.1404 - val_accuracy: 0.3477 - val_loss: 0.0346 - val_psnr: 14.6898 - val_ssim_metric: 0.1582
# Epoch 10/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.3137 - loss: 0.0437 - psnr: 14.1212 - ssim_metric: 0.1851 - val_accuracy: 0.3497 - val_loss: 0.0336 - val_psnr: 15.0725 - val_ssim_metric: 0.2094
# Epoch 11/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - accuracy: 0.3037 - loss: 0.0368 - psnr: 14.4299 - ssim_metric: 0.1701 - val_accuracy: 0.3577 - val_loss: 0.0320 - val_psnr: 15.0699 - val_ssim_metric: 0.1956
# Epoch 12/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 113ms/step - accuracy: 0.3884 - loss: 0.0302 - psnr: 15.3947 - ssim_metric: 0.1930 - val_accuracy: 0.3570 - val_loss: 0.0340 - val_psnr: 14.9055 - val_ssim_metric: 0.2100
# Epoch 13/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step - accuracy: 0.3640 - loss: 0.0339 - psnr: 14.9628 - ssim_metric: 0.2318 - val_accuracy: 0.3716 - val_loss: 0.0310 - val_psnr: 15.3172 - val_ssim_metric: 0.2389
# Epoch 14/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.3813 - loss: 0.0308 - psnr: 15.3450 - ssim_metric: 0.2189 - val_accuracy: 0.4173 - val_loss: 0.0275 - val_psnr: 15.7178 - val_ssim_metric: 0.2405
# Epoch 15/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.3593 - loss: 0.0327 - psnr: 15.1922 - ssim_metric: 0.2394 - val_accuracy: 0.3574 - val_loss: 0.0341 - val_psnr: 15.1786 - val_ssim_metric: 0.3313
# Epoch 16/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.4047 - loss: 0.0298 - psnr: 15.3995 - ssim_metric: 0.2096 - val_accuracy: 0.3527 - val_loss: 0.0309 - val_psnr: 15.2399 - val_ssim_metric: 0.3188
# Epoch 17/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.3918 - loss: 0.0295 - psnr: 15.4372 - ssim_metric: 0.2174 - val_accuracy: 0.4089 - val_loss: 0.0281 - val_psnr: 15.7292 - val_ssim_metric: 0.2677
# Epoch 18/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.3748 - loss: 0.0339 - psnr: 15.4392 - ssim_metric: 0.3282 - val_accuracy: 0.4213 - val_loss: 0.0269 - val_psnr: 16.0859 - val_ssim_metric: 0.3794
# Epoch 19/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - accuracy: 0.3598 - loss: 0.0310 - psnr: 15.2219 - ssim_metric: 0.2702 - val_accuracy: 0.4094 - val_loss: 0.0298 - val_psnr: 15.5051 - val_ssim_metric: 0.2825
# Epoch 20/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.4261 - loss: 0.0260 - psnr: 16.0978 - ssim_metric: 0.2748 - val_accuracy: 0.3964 - val_loss: 0.0312 - val_psnr: 15.4497 - val_ssim_metric: 0.2894
# Epoch 21/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 120ms/step - accuracy: 0.3944 - loss: 0.0308 - psnr: 15.4705 - ssim_metric: 0.3274 - val_accuracy: 0.3911 - val_loss: 0.0341 - val_psnr: 15.0834 - val_ssim_metric: 0.2841
# Epoch 22/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - accuracy: 0.4255 - loss: 0.0294 - psnr: 15.6956 - ssim_metric: 0.2865 - val_accuracy: 0.3979 - val_loss: 0.0290 - val_psnr: 15.4890 - val_ssim_metric: 0.2776
# Epoch 23/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - accuracy: 0.3958 - loss: 0.0301 - psnr: 15.6481 - ssim_metric: 0.3096 - val_accuracy: 0.3836 - val_loss: 0.0319 - val_psnr: 15.6583 - val_ssim_metric: 0.4281
# Epoch 24/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - accuracy: 0.4124 - loss: 0.0294 - psnr: 15.4768 - ssim_metric: 0.2481 - val_accuracy: 0.3507 - val_loss: 0.0325 - val_psnr: 15.1223 - val_ssim_metric: 0.3741
# Epoch 25/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.4008 - loss: 0.0282 - psnr: 15.6442 - ssim_metric: 0.2618 - val_accuracy: 0.4146 - val_loss: 0.0278 - val_psnr: 15.8084 - val_ssim_metric: 0.3054
# Epoch 26/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - accuracy: 0.3842 - loss: 0.0329 - psnr: 15.6142 - ssim_metric: 0.3905 - val_accuracy: 0.4068 - val_loss: 0.0296 - val_psnr: 15.6857 - val_ssim_metric: 0.3904
# Epoch 27/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - accuracy: 0.3689 - loss: 0.0307 - psnr: 15.2945 - ssim_metric: 0.3016 - val_accuracy: 0.4097 - val_loss: 0.0304 - val_psnr: 15.4484 - val_ssim_metric: 0.3097
# Epoch 28/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 119ms/step - accuracy: 0.4360 - loss: 0.0254 - psnr: 16.2085 - ssim_metric: 0.3067 - val_accuracy: 0.3918 - val_loss: 0.0340 - val_psnr: 15.3044 - val_ssim_metric: 0.3353
# Epoch 29/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - accuracy: 0.4007 - loss: 0.0307 - psnr: 15.5089 - ssim_metric: 0.3556 - val_accuracy: 0.3750 - val_loss: 0.0307 - val_psnr: 15.2734 - val_ssim_metric: 0.2826
# Epoch 30/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 123ms/step - accuracy: 0.4251 - loss: 0.0295 - psnr: 15.6976 - ssim_metric: 0.3071 - val_accuracy: 0.4120 - val_loss: 0.0270 - val_psnr: 15.8320 - val_ssim_metric: 0.3137
# Epoch 31/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 119ms/step - accuracy: 0.3994 - loss: 0.0300 - psnr: 15.6963 - ssim_metric: 0.3270 - val_accuracy: 0.3630 - val_loss: 0.0329 - val_psnr: 15.3768 - val_ssim_metric: 0.4309
# Epoch 32/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - accuracy: 0.4121 - loss: 0.0290 - psnr: 15.5258 - ssim_metric: 0.2587 - val_accuracy: 0.3558 - val_loss: 0.0328 - val_psnr: 15.1463 - val_ssim_metric: 0.3798
# Epoch 33/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.4015 - loss: 0.0281 - psnr: 15.6662 - ssim_metric: 0.2708 - val_accuracy: 0.4062 - val_loss: 0.0292 - val_psnr: 15.5673 - val_ssim_metric: 0.2946
# Epoch 34/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.3821 - loss: 0.0331 - psnr: 15.5946 - ssim_metric: 0.4033 - val_accuracy: 0.4074 - val_loss: 0.0295 - val_psnr: 15.6980 - val_ssim_metric: 0.3974
# Epoch 35/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.3732 - loss: 0.0304 - psnr: 15.3380 - ssim_metric: 0.3120 - val_accuracy: 0.4164 - val_loss: 0.0296 - val_psnr: 15.5575 - val_ssim_metric: 0.3153
# Epoch 36/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.4309 - loss: 0.0256 - psnr: 16.1903 - ssim_metric: 0.3162 - val_accuracy: 0.3927 - val_loss: 0.0312 - val_psnr: 15.4834 - val_ssim_metric: 0.3180
# Epoch 37/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.4006 - loss: 0.0307 - psnr: 15.4981 - ssim_metric: 0.3654 - val_accuracy: 0.3923 - val_loss: 0.0340 - val_psnr: 15.1115 - val_ssim_metric: 0.2992
# Epoch 38/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.4327 - loss: 0.0290 - psnr: 15.7838 - ssim_metric: 0.3139 - val_accuracy: 0.3932 - val_loss: 0.0277 - val_psnr: 15.6907 - val_ssim_metric: 0.3036
# Epoch 39/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 118ms/step - accuracy: 0.3936 - loss: 0.0305 - psnr: 15.6297 - ssim_metric: 0.3330 - val_accuracy: 0.3775 - val_loss: 0.0316 - val_psnr: 15.6112 - val_ssim_metric: 0.4410
# Epoch 40/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 119ms/step - accuracy: 0.4102 - loss: 0.0293 - psnr: 15.4891 - ssim_metric: 0.2598 - val_accuracy: 0.3617 - val_loss: 0.0308 - val_psnr: 15.3255 - val_ssim_metric: 0.3839
# Epoch 41/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - accuracy: 0.3986 - loss: 0.0285 - psnr: 15.5923 - ssim_metric: 0.2669 - val_accuracy: 0.4334 - val_loss: 0.0254 - val_psnr: 16.1849 - val_ssim_metric: 0.3421
# Epoch 42/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.3846 - loss: 0.0329 - psnr: 15.6181 - ssim_metric: 0.4111 - val_accuracy: 0.4025 - val_loss: 0.0293 - val_psnr: 15.7198 - val_ssim_metric: 0.4016
# Epoch 43/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.3681 - loss: 0.0303 - psnr: 15.3334 - ssim_metric: 0.3157 - val_accuracy: 0.4027 - val_loss: 0.0305 - val_psnr: 15.4189 - val_ssim_metric: 0.3064
# Epoch 44/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.4288 - loss: 0.0262 - psnr: 16.1304 - ssim_metric: 0.3184 - val_accuracy: 0.3896 - val_loss: 0.0312 - val_psnr: 15.4606 - val_ssim_metric: 0.3179
# Epoch 45/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.3987 - loss: 0.0307 - psnr: 15.4935 - ssim_metric: 0.3704 - val_accuracy: 0.3976 - val_loss: 0.0312 - val_psnr: 15.3808 - val_ssim_metric: 0.3092
# Epoch 46/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - accuracy: 0.4281 - loss: 0.0289 - psnr: 15.7812 - ssim_metric: 0.3168 - val_accuracy: 0.3918 - val_loss: 0.0277 - val_psnr: 15.6943 - val_ssim_metric: 0.3039
# Epoch 47/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.3911 - loss: 0.0305 - psnr: 15.6177 - ssim_metric: 0.3371 - val_accuracy: 0.3771 - val_loss: 0.0316 - val_psnr: 15.6044 - val_ssim_metric: 0.4414
# Epoch 48/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 113ms/step - accuracy: 0.4129 - loss: 0.0292 - psnr: 15.5171 - ssim_metric: 0.2638 - val_accuracy: 0.3609 - val_loss: 0.0308 - val_psnr: 15.3245 - val_ssim_metric: 0.3843
# Epoch 49/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 119ms/step - accuracy: 0.4008 - loss: 0.0280 - psnr: 15.6792 - ssim_metric: 0.2776 - val_accuracy: 0.4140 - val_loss: 0.0276 - val_psnr: 15.8254 - val_ssim_metric: 0.3087
# Epoch 50/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - accuracy: 0.3849 - loss: 0.0327 - psnr: 15.6607 - ssim_metric: 0.4196 - val_accuracy: 0.4021 - val_loss: 0.0303 - val_psnr: 15.5431 - val_ssim_metric: 0.3881
# Epoch 51/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.3698 - loss: 0.0305 - psnr: 15.3156 - ssim_metric: 0.3208 - val_accuracy: 0.4221 - val_loss: 0.0289 - val_psnr: 15.6781 - val_ssim_metric: 0.3157
# Epoch 52/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.4295 - loss: 0.0261 - psnr: 16.1419 - ssim_metric: 0.3226 - val_accuracy: 0.3909 - val_loss: 0.0310 - val_psnr: 15.5018 - val_ssim_metric: 0.3141
# Epoch 53/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.3992 - loss: 0.0306 - psnr: 15.5053 - ssim_metric: 0.3751 - val_accuracy: 0.3977 - val_loss: 0.0312 - val_psnr: 15.3820 - val_ssim_metric: 0.3094
# Epoch 54/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.4259 - loss: 0.0291 - psnr: 15.7549 - ssim_metric: 0.3203 - val_accuracy: 0.3915 - val_loss: 0.0276 - val_psnr: 15.6976 - val_ssim_metric: 0.3040
# Epoch 55/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.3909 - loss: 0.0305 - psnr: 15.6243 - ssim_metric: 0.3412 - val_accuracy: 0.3887 - val_loss: 0.0310 - val_psnr: 15.7348 - val_ssim_metric: 0.4438
# Epoch 56/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.4129 - loss: 0.0291 - psnr: 15.5232 - ssim_metric: 0.2660 - val_accuracy: 0.3598 - val_loss: 0.0308 - val_psnr: 15.3229 - val_ssim_metric: 0.3844
# Epoch 57/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.4006 - loss: 0.0280 - psnr: 15.6835 - ssim_metric: 0.2800 - val_accuracy: 0.4136 - val_loss: 0.0276 - val_psnr: 15.8283 - val_ssim_metric: 0.3088
# Epoch 58/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - accuracy: 0.3847 - loss: 0.0326 - psnr: 15.6915 - ssim_metric: 0.4315 - val_accuracy: 0.4127 - val_loss: 0.0299 - val_psnr: 15.5744 - val_ssim_metric: 0.3650
# Epoch 59/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 131ms/step - accuracy: 0.3696 - loss: 0.0304 - psnr: 15.3278 - ssim_metric: 0.3245 - val_accuracy: 0.4119 - val_loss: 0.0304 - val_psnr: 15.4757 - val_ssim_metric: 0.3074
# Epoch 60/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - accuracy: 0.4311 - loss: 0.0254 - psnr: 16.2142 - ssim_metric: 0.3281 - val_accuracy: 0.3914 - val_loss: 0.0312 - val_psnr: 15.4784 - val_ssim_metric: 0.3126
# Epoch 61/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.4016 - loss: 0.0306 - psnr: 15.5197 - ssim_metric: 0.3794 - val_accuracy: 0.3925 - val_loss: 0.0339 - val_psnr: 15.1255 - val_ssim_metric: 0.3003
# Epoch 62/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.4337 - loss: 0.0289 - psnr: 15.8060 - ssim_metric: 0.3235 - val_accuracy: 0.3922 - val_loss: 0.0276 - val_psnr: 15.7010 - val_ssim_metric: 0.3045
# Epoch 63/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.3923 - loss: 0.0306 - psnr: 15.6309 - ssim_metric: 0.3417 - val_accuracy: 0.3771 - val_loss: 0.0316 - val_psnr: 15.6056 - val_ssim_metric: 0.4427
# Epoch 64/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.4098 - loss: 0.0292 - psnr: 15.5078 - ssim_metric: 0.2666 - val_accuracy: 0.3619 - val_loss: 0.0300 - val_psnr: 15.3857 - val_ssim_metric: 0.3948
# Epoch 65/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.4000 - loss: 0.0279 - psnr: 15.6871 - ssim_metric: 0.2817 - val_accuracy: 0.4239 - val_loss: 0.0272 - val_psnr: 15.8957 - val_ssim_metric: 0.3148
# Epoch 66/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.3863 - loss: 0.0327 - psnr: 15.6601 - ssim_metric: 0.4278 - val_accuracy: 0.4071 - val_loss: 0.0294 - val_psnr: 15.7178 - val_ssim_metric: 0.4008
# Epoch 67/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 117ms/step - accuracy: 0.3711 - loss: 0.0303 - psnr: 15.3501 - ssim_metric: 0.3269 - val_accuracy: 0.4059 - val_loss: 0.0306 - val_psnr: 15.4209 - val_ssim_metric: 0.3077
# Epoch 68/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 129ms/step - accuracy: 0.4320 - loss: 0.0257 - psnr: 16.1658 - ssim_metric: 0.3215 - val_accuracy: 0.3859 - val_loss: 0.0321 - val_psnr: 15.5454 - val_ssim_metric: 0.3580
# Epoch 69/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 115ms/step - accuracy: 0.4019 - loss: 0.0304 - psnr: 15.5400 - ssim_metric: 0.3799 - val_accuracy: 0.4072 - val_loss: 0.0284 - val_psnr: 15.6713 - val_ssim_metric: 0.3124
# Epoch 70/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.4313 - loss: 0.0288 - psnr: 15.8054 - ssim_metric: 0.3258 - val_accuracy: 0.3963 - val_loss: 0.0301 - val_psnr: 15.3654 - val_ssim_metric: 0.2982
# Epoch 71/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.3927 - loss: 0.0304 - psnr: 15.6499 - ssim_metric: 0.3480 - val_accuracy: 0.3772 - val_loss: 0.0316 - val_psnr: 15.6100 - val_ssim_metric: 0.4432
# Epoch 72/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.4132 - loss: 0.0291 - psnr: 15.5281 - ssim_metric: 0.2702 - val_accuracy: 0.3587 - val_loss: 0.0308 - val_psnr: 15.3236 - val_ssim_metric: 0.3847
# Epoch 73/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - accuracy: 0.3965 - loss: 0.0287 - psnr: 15.5799 - ssim_metric: 0.2759 - val_accuracy: 0.4120 - val_loss: 0.0275 - val_psnr: 15.8311 - val_ssim_metric: 0.3087
# Epoch 74/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.3857 - loss: 0.0327 - psnr: 15.6525 - ssim_metric: 0.4317 - val_accuracy: 0.4279 - val_loss: 0.0263 - val_psnr: 16.2120 - val_ssim_metric: 0.4351
# Epoch 75/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.3684 - loss: 0.0303 - psnr: 15.3472 - ssim_metric: 0.3289 - val_accuracy: 0.4038 - val_loss: 0.0305 - val_psnr: 15.4268 - val_ssim_metric: 0.3078
# Epoch 76/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 112ms/step - accuracy: 0.4312 - loss: 0.0254 - psnr: 16.2250 - ssim_metric: 0.3332 - val_accuracy: 0.4007 - val_loss: 0.0308 - val_psnr: 15.5384 - val_ssim_metric: 0.3169
# Epoch 77/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step - accuracy: 0.4028 - loss: 0.0304 - psnr: 15.5437 - ssim_metric: 0.3822 - val_accuracy: 0.3883 - val_loss: 0.0320 - val_psnr: 15.4002 - val_ssim_metric: 0.3217
# Epoch 78/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step - accuracy: 0.4319 - loss: 0.0291 - psnr: 15.7675 - ssim_metric: 0.3278 - val_accuracy: 0.4111 - val_loss: 0.0286 - val_psnr: 15.6222 - val_ssim_metric: 0.3096
# Epoch 79/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.3962 - loss: 0.0302 - psnr: 15.6847 - ssim_metric: 0.3514 - val_accuracy: 0.3669 - val_loss: 0.0328 - val_psnr: 15.4002 - val_ssim_metric: 0.4308
# Epoch 80/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.4111 - loss: 0.0293 - psnr: 15.5015 - ssim_metric: 0.2704 - val_accuracy: 0.3598 - val_loss: 0.0307 - val_psnr: 15.3313 - val_ssim_metric: 0.3851
# Epoch 81/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.3970 - loss: 0.0287 - psnr: 15.5818 - ssim_metric: 0.2771 - val_accuracy: 0.4223 - val_loss: 0.0271 - val_psnr: 15.8973 - val_ssim_metric: 0.3147
# Epoch 82/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.3859 - loss: 0.0327 - psnr: 15.6586 - ssim_metric: 0.4354 - val_accuracy: 0.4280 - val_loss: 0.0263 - val_psnr: 16.2149 - val_ssim_metric: 0.4356
# Epoch 83/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.3687 - loss: 0.0303 - psnr: 15.3525 - ssim_metric: 0.3315 - val_accuracy: 0.4038 - val_loss: 0.0305 - val_psnr: 15.4288 - val_ssim_metric: 0.3080
# Epoch 84/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.4317 - loss: 0.0254 - psnr: 16.2290 - ssim_metric: 0.3358 - val_accuracy: 0.4006 - val_loss: 0.0308 - val_psnr: 15.5405 - val_ssim_metric: 0.3171
# Epoch 85/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 112ms/step - accuracy: 0.4020 - loss: 0.0305 - psnr: 15.5352 - ssim_metric: 0.3883 - val_accuracy: 0.3926 - val_loss: 0.0338 - val_psnr: 15.1340 - val_ssim_metric: 0.3007
# Epoch 86/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - accuracy: 0.4300 - loss: 0.0292 - psnr: 15.7470 - ssim_metric: 0.3283 - val_accuracy: 0.3957 - val_loss: 0.0269 - val_psnr: 15.8328 - val_ssim_metric: 0.3085
# Epoch 87/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - accuracy: 0.3869 - loss: 0.0305 - psnr: 15.6232 - ssim_metric: 0.3535 - val_accuracy: 0.4007 - val_loss: 0.0319 - val_psnr: 15.6861 - val_ssim_metric: 0.4358
# Epoch 88/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.4141 - loss: 0.0289 - psnr: 15.5385 - ssim_metric: 0.2739 - val_accuracy: 0.3779 - val_loss: 0.0300 - val_psnr: 15.5625 - val_ssim_metric: 0.3921
# Epoch 89/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.4026 - loss: 0.0279 - psnr: 15.7033 - ssim_metric: 0.2886 - val_accuracy: 0.4062 - val_loss: 0.0290 - val_psnr: 15.5908 - val_ssim_metric: 0.2963
# Epoch 90/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - accuracy: 0.3835 - loss: 0.0328 - psnr: 15.6416 - ssim_metric: 0.4378 - val_accuracy: 0.4072 - val_loss: 0.0293 - val_psnr: 15.7248 - val_ssim_metric: 0.4032
# Epoch 91/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.3744 - loss: 0.0302 - psnr: 15.3769 - ssim_metric: 0.3331 - val_accuracy: 0.4147 - val_loss: 0.0295 - val_psnr: 15.5779 - val_ssim_metric: 0.3175
# Epoch 92/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.4301 - loss: 0.0260 - psnr: 16.1665 - ssim_metric: 0.3352 - val_accuracy: 0.3891 - val_loss: 0.0312 - val_psnr: 15.4744 - val_ssim_metric: 0.3193
# Epoch 93/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.3987 - loss: 0.0301 - psnr: 15.5800 - ssim_metric: 0.3950 - val_accuracy: 0.3979 - val_loss: 0.0312 - val_psnr: 15.3851 - val_ssim_metric: 0.3104
# Epoch 94/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - accuracy: 0.4340 - loss: 0.0288 - psnr: 15.8201 - ssim_metric: 0.3320 - val_accuracy: 0.3980 - val_loss: 0.0287 - val_psnr: 15.5348 - val_ssim_metric: 0.2880
# Epoch 95/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 120ms/step - accuracy: 0.3941 - loss: 0.0305 - psnr: 15.6661 - ssim_metric: 0.3527 - val_accuracy: 0.3774 - val_loss: 0.0315 - val_psnr: 15.6144 - val_ssim_metric: 0.4440
# Epoch 96/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - accuracy: 0.4125 - loss: 0.0288 - psnr: 15.5636 - ssim_metric: 0.2762 - val_accuracy: 0.3656 - val_loss: 0.0303 - val_psnr: 15.4076 - val_ssim_metric: 0.3962
# Epoch 97/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - accuracy: 0.4011 - loss: 0.0279 - psnr: 15.7056 - ssim_metric: 0.2888 - val_accuracy: 0.4059 - val_loss: 0.0290 - val_psnr: 15.5965 - val_ssim_metric: 0.2958
# Epoch 98/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.3871 - loss: 0.0325 - psnr: 15.6850 - ssim_metric: 0.4423 - val_accuracy: 0.4074 - val_loss: 0.0293 - val_psnr: 15.7257 - val_ssim_metric: 0.4032
# Epoch 99/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.3756 - loss: 0.0301 - psnr: 15.3807 - ssim_metric: 0.3347 - val_accuracy: 0.4053 - val_loss: 0.0305 - val_psnr: 15.4297 - val_ssim_metric: 0.3085
# Epoch 100/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.4320 - loss: 0.0253 - psnr: 16.2380 - ssim_metric: 0.3392 - val_accuracy: 0.3916 - val_loss: 0.0311 - val_psnr: 15.4976 - val_ssim_metric: 0.3197
# Epoch 101/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.4012 - loss: 0.0301 - psnr: 15.5990 - ssim_metric: 0.3970 - val_accuracy: 0.3928 - val_loss: 0.0339 - val_psnr: 15.1212 - val_ssim_metric: 0.3008
# Epoch 102/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - accuracy: 0.4349 - loss: 0.0290 - psnr: 15.7938 - ssim_metric: 0.3332 - val_accuracy: 0.3982 - val_loss: 0.0287 - val_psnr: 15.5301 - val_ssim_metric: 0.2879
# Epoch 103/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.3960 - loss: 0.0304 - psnr: 15.6860 - ssim_metric: 0.3543 - val_accuracy: 0.3892 - val_loss: 0.0309 - val_psnr: 15.7520 - val_ssim_metric: 0.4459
# Epoch 104/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 120ms/step - accuracy: 0.4134 - loss: 0.0290 - psnr: 15.5371 - ssim_metric: 0.2753 - val_accuracy: 0.3599 - val_loss: 0.0300 - val_psnr: 15.3873 - val_ssim_metric: 0.3950
# Epoch 105/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - accuracy: 0.3984 - loss: 0.0282 - psnr: 15.6432 - ssim_metric: 0.2816 - val_accuracy: 0.4182 - val_loss: 0.0262 - val_psnr: 16.0594 - val_ssim_metric: 0.3366
# Epoch 106/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 115ms/step - accuracy: 0.3864 - loss: 0.0326 - psnr: 15.6709 - ssim_metric: 0.4425 - val_accuracy: 0.4059 - val_loss: 0.0293 - val_psnr: 15.7333 - val_ssim_metric: 0.4030
# Epoch 107/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.3697 - loss: 0.0302 - psnr: 15.3625 - ssim_metric: 0.3360 - val_accuracy: 0.4038 - val_loss: 0.0305 - val_psnr: 15.4333 - val_ssim_metric: 0.3083
# Epoch 108/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.4303 - loss: 0.0260 - psnr: 16.1722 - ssim_metric: 0.3373 - val_accuracy: 0.3989 - val_loss: 0.0308 - val_psnr: 15.5318 - val_ssim_metric: 0.3168
# Epoch 109/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.4006 - loss: 0.0304 - psnr: 15.5383 - ssim_metric: 0.3935 - val_accuracy: 0.3979 - val_loss: 0.0311 - val_psnr: 15.4022 - val_ssim_metric: 0.3098
# Epoch 110/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.4310 - loss: 0.0287 - psnr: 15.8207 - ssim_metric: 0.3334 - val_accuracy: 0.3904 - val_loss: 0.0276 - val_psnr: 15.7105 - val_ssim_metric: 0.3041
# Epoch 111/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.3897 - loss: 0.0305 - psnr: 15.6332 - ssim_metric: 0.3539 - val_accuracy: 0.3768 - val_loss: 0.0316 - val_psnr: 15.5982 - val_ssim_metric: 0.4434
# Epoch 112/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.4130 - loss: 0.0289 - psnr: 15.5489 - ssim_metric: 0.2759 - val_accuracy: 0.3591 - val_loss: 0.0300 - val_psnr: 15.3835 - val_ssim_metric: 0.3954
# Epoch 113/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 112ms/step - accuracy: 0.3965 - loss: 0.0286 - psnr: 15.5943 - ssim_metric: 0.2813 - val_accuracy: 0.4113 - val_loss: 0.0274 - val_psnr: 15.8378 - val_ssim_metric: 0.3090
# Epoch 114/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 129ms/step - accuracy: 0.3857 - loss: 0.0326 - psnr: 15.6820 - ssim_metric: 0.4459 - val_accuracy: 0.4227 - val_loss: 0.0271 - val_psnr: 16.0492 - val_ssim_metric: 0.4255
# Epoch 115/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 116ms/step - accuracy: 0.3679 - loss: 0.0302 - psnr: 15.3614 - ssim_metric: 0.3371 - val_accuracy: 0.4093 - val_loss: 0.0294 - val_psnr: 15.5942 - val_ssim_metric: 0.3167
# Epoch 116/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.4316 - loss: 0.0253 - psnr: 16.2391 - ssim_metric: 0.3408 - val_accuracy: 0.3999 - val_loss: 0.0308 - val_psnr: 15.5419 - val_ssim_metric: 0.3170
# Epoch 117/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.4019 - loss: 0.0304 - psnr: 15.5451 - ssim_metric: 0.3949 - val_accuracy: 0.3926 - val_loss: 0.0337 - val_psnr: 15.1461 - val_ssim_metric: 0.3008
# Epoch 118/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.4314 - loss: 0.0290 - psnr: 15.7935 - ssim_metric: 0.3345 - val_accuracy: 0.3910 - val_loss: 0.0275 - val_psnr: 15.7132 - val_ssim_metric: 0.3042
# Epoch 119/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.3919 - loss: 0.0305 - psnr: 15.6530 - ssim_metric: 0.3555 - val_accuracy: 0.3884 - val_loss: 0.0309 - val_psnr: 15.7357 - val_ssim_metric: 0.4455
# Epoch 120/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.4100 - loss: 0.0291 - psnr: 15.5311 - ssim_metric: 0.2749 - val_accuracy: 0.3585 - val_loss: 0.0300 - val_psnr: 15.3840 - val_ssim_metric: 0.3948
# Epoch 121/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.3999 - loss: 0.0278 - psnr: 15.7084 - ssim_metric: 0.2904 - val_accuracy: 0.4233 - val_loss: 0.0271 - val_psnr: 15.9076 - val_ssim_metric: 0.3153
# Epoch 122/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - accuracy: 0.3843 - loss: 0.0328 - psnr: 15.6467 - ssim_metric: 0.4443 - val_accuracy: 0.4066 - val_loss: 0.0293 - val_psnr: 15.7343 - val_ssim_metric: 0.4036
# Epoch 123/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step - accuracy: 0.3732 - loss: 0.0302 - psnr: 15.3666 - ssim_metric: 0.3390 - val_accuracy: 0.4193 - val_loss: 0.0289 - val_psnr: 15.6653 - val_ssim_metric: 0.3136
# Epoch 124/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 131ms/step - accuracy: 0.4367 - loss: 0.0251 - psnr: 16.3225 - ssim_metric: 0.3434 - val_accuracy: 0.3772 - val_loss: 0.0327 - val_psnr: 15.2683 - val_ssim_metric: 0.3377
# Epoch 125/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - accuracy: 0.4045 - loss: 0.0301 - psnr: 15.6057 - ssim_metric: 0.3958 - val_accuracy: 0.3963 - val_loss: 0.0318 - val_psnr: 15.2281 - val_ssim_metric: 0.2887
# Epoch 126/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.4378 - loss: 0.0288 - psnr: 15.8421 - ssim_metric: 0.3356 - val_accuracy: 0.3885 - val_loss: 0.0286 - val_psnr: 15.5442 - val_ssim_metric: 0.3027
# Epoch 127/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.3952 - loss: 0.0302 - psnr: 15.6965 - ssim_metric: 0.3579 - val_accuracy: 0.3777 - val_loss: 0.0315 - val_psnr: 15.6245 - val_ssim_metric: 0.4429
# Epoch 128/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.4105 - loss: 0.0291 - psnr: 15.5265 - ssim_metric: 0.2744 - val_accuracy: 0.3566 - val_loss: 0.0306 - val_psnr: 15.3323 - val_ssim_metric: 0.3803
# Epoch 129/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.3963 - loss: 0.0285 - psnr: 15.5983 - ssim_metric: 0.2783 - val_accuracy: 0.4227 - val_loss: 0.0270 - val_psnr: 15.9133 - val_ssim_metric: 0.3133
# Epoch 130/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.3866 - loss: 0.0325 - psnr: 15.6838 - ssim_metric: 0.4445 - val_accuracy: 0.4292 - val_loss: 0.0262 - val_psnr: 16.2414 - val_ssim_metric: 0.4321
# Epoch 131/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.3683 - loss: 0.0300 - psnr: 15.3830 - ssim_metric: 0.3272 - val_accuracy: 0.4031 - val_loss: 0.0300 - val_psnr: 15.4873 - val_ssim_metric: 0.2963
# Epoch 132/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 117ms/step - accuracy: 0.4331 - loss: 0.0251 - psnr: 16.2650 - ssim_metric: 0.3331 - val_accuracy: 0.4035 - val_loss: 0.0301 - val_psnr: 15.6436 - val_ssim_metric: 0.3015
# Epoch 133/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 123ms/step - accuracy: 0.4054 - loss: 0.0297 - psnr: 15.6327 - ssim_metric: 0.3681 - val_accuracy: 0.3823 - val_loss: 0.0313 - val_psnr: 15.4755 - val_ssim_metric: 0.2828
# Epoch 134/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 118ms/step - accuracy: 0.4231 - loss: 0.0281 - psnr: 15.9030 - ssim_metric: 0.3005 - val_accuracy: 0.4127 - val_loss: 0.0282 - val_psnr: 15.6606 - val_ssim_metric: 0.2878
# Epoch 135/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.4166 - loss: 0.0287 - psnr: 16.0019 - ssim_metric: 0.3401 - val_accuracy: 0.3817 - val_loss: 0.0316 - val_psnr: 15.6023 - val_ssim_metric: 0.4180
# Epoch 136/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.4191 - loss: 0.0280 - psnr: 15.6943 - ssim_metric: 0.2508 - val_accuracy: 0.4009 - val_loss: 0.0278 - val_psnr: 15.7848 - val_ssim_metric: 0.3645
# Epoch 137/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.4012 - loss: 0.0280 - psnr: 15.6803 - ssim_metric: 0.2643 - val_accuracy: 0.4324 - val_loss: 0.0264 - val_psnr: 16.0107 - val_ssim_metric: 0.2780
# Epoch 138/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.3887 - loss: 0.0305 - psnr: 15.8677 - ssim_metric: 0.4108 - val_accuracy: 0.4679 - val_loss: 0.0238 - val_psnr: 16.6881 - val_ssim_metric: 0.4142
# Epoch 139/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.3984 - loss: 0.0276 - psnr: 15.7789 - ssim_metric: 0.3052 - val_accuracy: 0.4529 - val_loss: 0.0295 - val_psnr: 15.6562 - val_ssim_metric: 0.3105
# Epoch 140/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.4439 - loss: 0.0254 - psnr: 16.3139 - ssim_metric: 0.3318 - val_accuracy: 0.4157 - val_loss: 0.0280 - val_psnr: 16.0174 - val_ssim_metric: 0.2939
# Epoch 141/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - accuracy: 0.4243 - loss: 0.0274 - psnr: 15.9449 - ssim_metric: 0.3521 - val_accuracy: 0.3784 - val_loss: 0.0302 - val_psnr: 15.4002 - val_ssim_metric: 0.2694
# Epoch 142/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 116ms/step - accuracy: 0.4501 - loss: 0.0259 - psnr: 16.2778 - ssim_metric: 0.3057 - val_accuracy: 0.4246 - val_loss: 0.0255 - val_psnr: 16.0674 - val_ssim_metric: 0.2939
# Epoch 143/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step - accuracy: 0.4509 - loss: 0.0255 - psnr: 16.5914 - ssim_metric: 0.3514 - val_accuracy: 0.4131 - val_loss: 0.0279 - val_psnr: 16.0295 - val_ssim_metric: 0.3960
# Epoch 144/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.4233 - loss: 0.0271 - psnr: 15.8241 - ssim_metric: 0.2421 - val_accuracy: 0.4520 - val_loss: 0.0248 - val_psnr: 16.2848 - val_ssim_metric: 0.3699
# Epoch 145/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.4254 - loss: 0.0262 - psnr: 15.9606 - ssim_metric: 0.2692 - val_accuracy: 0.4660 - val_loss: 0.0247 - val_psnr: 16.3420 - val_ssim_metric: 0.2932
# Epoch 146/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.4101 - loss: 0.0267 - psnr: 16.3260 - ssim_metric: 0.4288 - val_accuracy: 0.4947 - val_loss: 0.0238 - val_psnr: 16.8463 - val_ssim_metric: 0.4244
# Epoch 147/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - accuracy: 0.4463 - loss: 0.0258 - psnr: 16.1123 - ssim_metric: 0.3281 - val_accuracy: 0.4468 - val_loss: 0.0265 - val_psnr: 16.1218 - val_ssim_metric: 0.3004
# Epoch 148/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.4622 - loss: 0.0229 - psnr: 16.7053 - ssim_metric: 0.3330 - val_accuracy: 0.4551 - val_loss: 0.0263 - val_psnr: 16.2745 - val_ssim_metric: 0.2806
# Epoch 149/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.4655 - loss: 0.0244 - psnr: 16.4306 - ssim_metric: 0.3568 - val_accuracy: 0.3970 - val_loss: 0.0298 - val_psnr: 15.5733 - val_ssim_metric: 0.2817
# Epoch 150/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - accuracy: 0.4868 - loss: 0.0236 - psnr: 16.7582 - ssim_metric: 0.3205 - val_accuracy: 0.4577 - val_loss: 0.0240 - val_psnr: 16.3472 - val_ssim_metric: 0.3000
# Epoch 151/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step - accuracy: 0.5058 - loss: 0.0221 - psnr: 17.2981 - ssim_metric: 0.3588 - val_accuracy: 0.4357 - val_loss: 0.0235 - val_psnr: 16.7110 - val_ssim_metric: 0.4215
# Epoch 152/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - accuracy: 0.4350 - loss: 0.0254 - psnr: 16.0690 - ssim_metric: 0.2542 - val_accuracy: 0.5238 - val_loss: 0.0202 - val_psnr: 17.2176 - val_ssim_metric: 0.3818
# Epoch 153/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - accuracy: 0.4543 - loss: 0.0236 - psnr: 16.4448 - ssim_metric: 0.2763 - val_accuracy: 0.4807 - val_loss: 0.0234 - val_psnr: 16.5137 - val_ssim_metric: 0.2972
# Epoch 154/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.4253 - loss: 0.0247 - psnr: 16.6224 - ssim_metric: 0.4444 - val_accuracy: 0.4987 - val_loss: 0.0209 - val_psnr: 17.0685 - val_ssim_metric: 0.3897
# Epoch 155/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.5071 - loss: 0.0221 - psnr: 16.7857 - ssim_metric: 0.3405 - val_accuracy: 0.4843 - val_loss: 0.0227 - val_psnr: 16.7280 - val_ssim_metric: 0.3065
# Epoch 156/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.4963 - loss: 0.0202 - psnr: 17.2145 - ssim_metric: 0.3383 - val_accuracy: 0.4924 - val_loss: 0.0215 - val_psnr: 17.0553 - val_ssim_metric: 0.3180
# Epoch 157/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.5061 - loss: 0.0204 - psnr: 17.1632 - ssim_metric: 0.3819 - val_accuracy: 0.4395 - val_loss: 0.0257 - val_psnr: 16.1995 - val_ssim_metric: 0.2944
# Epoch 158/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.5437 - loss: 0.0202 - psnr: 17.4401 - ssim_metric: 0.3352 - val_accuracy: 0.4881 - val_loss: 0.0209 - val_psnr: 16.9413 - val_ssim_metric: 0.3067
# Epoch 159/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - accuracy: 0.5409 - loss: 0.0192 - psnr: 17.8574 - ssim_metric: 0.3704 - val_accuracy: 0.4744 - val_loss: 0.0214 - val_psnr: 17.2120 - val_ssim_metric: 0.4238
# Epoch 160/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - accuracy: 0.4745 - loss: 0.0221 - psnr: 16.6851 - ssim_metric: 0.2716 - val_accuracy: 0.5625 - val_loss: 0.0187 - val_psnr: 17.6413 - val_ssim_metric: 0.3967
# Epoch 161/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 123ms/step - accuracy: 0.4946 - loss: 0.0210 - psnr: 16.8958 - ssim_metric: 0.2919 - val_accuracy: 0.5371 - val_loss: 0.0199 - val_psnr: 17.5426 - val_ssim_metric: 0.3354
# Epoch 162/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 113ms/step - accuracy: 0.4633 - loss: 0.0216 - psnr: 17.2093 - ssim_metric: 0.4525 - val_accuracy: 0.5111 - val_loss: 0.0190 - val_psnr: 17.4037 - val_ssim_metric: 0.3678
# Epoch 163/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - accuracy: 0.5388 - loss: 0.0181 - psnr: 17.5695 - ssim_metric: 0.3513 - val_accuracy: 0.5414 - val_loss: 0.0193 - val_psnr: 17.4103 - val_ssim_metric: 0.3224
# Epoch 164/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.5381 - loss: 0.0178 - psnr: 17.7192 - ssim_metric: 0.3460 - val_accuracy: 0.5379 - val_loss: 0.0183 - val_psnr: 17.6778 - val_ssim_metric: 0.3322
# Epoch 165/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.5572 - loss: 0.0177 - psnr: 17.9076 - ssim_metric: 0.3970 - val_accuracy: 0.4805 - val_loss: 0.0222 - val_psnr: 16.7936 - val_ssim_metric: 0.3021
# Epoch 166/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.5795 - loss: 0.0167 - psnr: 18.2270 - ssim_metric: 0.3459 - val_accuracy: 0.5033 - val_loss: 0.0210 - val_psnr: 17.0085 - val_ssim_metric: 0.3111
# Epoch 167/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.5789 - loss: 0.0164 - psnr: 18.4957 - ssim_metric: 0.3802 - val_accuracy: 0.5465 - val_loss: 0.0166 - val_psnr: 18.2258 - val_ssim_metric: 0.4507
# Epoch 168/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.5245 - loss: 0.0186 - psnr: 17.4418 - ssim_metric: 0.2925 - val_accuracy: 0.6351 - val_loss: 0.0136 - val_psnr: 18.8287 - val_ssim_metric: 0.4247
# Epoch 169/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 118ms/step - accuracy: 0.5594 - loss: 0.0168 - psnr: 17.9295 - ssim_metric: 0.3196 - val_accuracy: 0.5935 - val_loss: 0.0160 - val_psnr: 18.2287 - val_ssim_metric: 0.3416
# Epoch 170/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 123ms/step - accuracy: 0.5151 - loss: 0.0184 - psnr: 17.8413 - ssim_metric: 0.4496 - val_accuracy: 0.5921 - val_loss: 0.0144 - val_psnr: 18.6594 - val_ssim_metric: 0.4143
# Epoch 171/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 123ms/step - accuracy: 0.6024 - loss: 0.0153 - psnr: 18.4193 - ssim_metric: 0.3737 - val_accuracy: 0.5556 - val_loss: 0.0189 - val_psnr: 17.6909 - val_ssim_metric: 0.3386
# Epoch 172/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.5965 - loss: 0.0150 - psnr: 18.5228 - ssim_metric: 0.3604 - val_accuracy: 0.5706 - val_loss: 0.0164 - val_psnr: 18.1530 - val_ssim_metric: 0.3462
# Epoch 173/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.6178 - loss: 0.0136 - psnr: 18.8850 - ssim_metric: 0.4181 - val_accuracy: 0.5276 - val_loss: 0.0179 - val_psnr: 17.5761 - val_ssim_metric: 0.3376
# Epoch 174/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.6366 - loss: 0.0137 - psnr: 18.9716 - ssim_metric: 0.3728 - val_accuracy: 0.5904 - val_loss: 0.0157 - val_psnr: 18.2707 - val_ssim_metric: 0.3518
# Epoch 175/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.6215 - loss: 0.0143 - psnr: 19.0910 - ssim_metric: 0.3978 - val_accuracy: 0.6332 - val_loss: 0.0127 - val_psnr: 19.1593 - val_ssim_metric: 0.4598
# Epoch 176/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.5809 - loss: 0.0159 - psnr: 18.1421 - ssim_metric: 0.3212 - val_accuracy: 0.7020 - val_loss: 0.0107 - val_psnr: 19.8758 - val_ssim_metric: 0.4529
# Epoch 177/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - accuracy: 0.5849 - loss: 0.0170 - psnr: 18.0833 - ssim_metric: 0.3282 - val_accuracy: 0.6038 - val_loss: 0.0145 - val_psnr: 18.5871 - val_ssim_metric: 0.3564
# Epoch 178/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - accuracy: 0.5623 - loss: 0.0162 - psnr: 18.4215 - ssim_metric: 0.4510 - val_accuracy: 0.6292 - val_loss: 0.0178 - val_psnr: 18.7419 - val_ssim_metric: 0.4414
# Epoch 179/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - accuracy: 0.6530 - loss: 0.0127 - psnr: 19.1686 - ssim_metric: 0.4008 - val_accuracy: 0.6263 - val_loss: 0.0162 - val_psnr: 18.4122 - val_ssim_metric: 0.3717
# Epoch 180/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step - accuracy: 0.6438 - loss: 0.0129 - psnr: 19.1007 - ssim_metric: 0.3833 - val_accuracy: 0.6159 - val_loss: 0.0136 - val_psnr: 18.8912 - val_ssim_metric: 0.3844
# Epoch 181/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.6450 - loss: 0.0136 - psnr: 19.1857 - ssim_metric: 0.4360 - val_accuracy: 0.5273 - val_loss: 0.0208 - val_psnr: 17.4930 - val_ssim_metric: 0.3235
# Epoch 182/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.6539 - loss: 0.0122 - psnr: 19.4195 - ssim_metric: 0.3902 - val_accuracy: 0.6325 - val_loss: 0.0144 - val_psnr: 18.5403 - val_ssim_metric: 0.3767
# Epoch 183/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - accuracy: 0.6556 - loss: 0.0130 - psnr: 19.4033 - ssim_metric: 0.4117 - val_accuracy: 0.6776 - val_loss: 0.0106 - val_psnr: 19.9026 - val_ssim_metric: 0.4793
# Epoch 184/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - accuracy: 0.5941 - loss: 0.0151 - psnr: 18.4032 - ssim_metric: 0.3388 - val_accuracy: 0.7311 - val_loss: 0.0097 - val_psnr: 20.3139 - val_ssim_metric: 0.4722
# Epoch 185/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.6475 - loss: 0.0125 - psnr: 19.1804 - ssim_metric: 0.3693 - val_accuracy: 0.6751 - val_loss: 0.0117 - val_psnr: 19.4826 - val_ssim_metric: 0.3884
# Epoch 186/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.6453 - loss: 0.0122 - psnr: 19.3878 - ssim_metric: 0.4760 - val_accuracy: 0.7076 - val_loss: 0.0099 - val_psnr: 20.2166 - val_ssim_metric: 0.4640
# Epoch 187/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - accuracy: 0.6940 - loss: 0.0109 - psnr: 19.7708 - ssim_metric: 0.4200 - val_accuracy: 0.6753 - val_loss: 0.0118 - val_psnr: 19.4222 - val_ssim_metric: 0.4049
# Epoch 188/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step - accuracy: 0.6778 - loss: 0.0126 - psnr: 19.5512 - ssim_metric: 0.3927 - val_accuracy: 0.6091 - val_loss: 0.0173 - val_psnr: 18.5667 - val_ssim_metric: 0.3951
# Epoch 189/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 129ms/step - accuracy: 0.6984 - loss: 0.0112 - psnr: 20.0730 - ssim_metric: 0.4553 - val_accuracy: 0.6642 - val_loss: 0.0116 - val_psnr: 19.5055 - val_ssim_metric: 0.3930
# Epoch 190/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - accuracy: 0.7074 - loss: 0.0100 - psnr: 20.2146 - ssim_metric: 0.4122 - val_accuracy: 0.5967 - val_loss: 0.0205 - val_psnr: 17.7273 - val_ssim_metric: 0.3715
# Epoch 191/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.6976 - loss: 0.0110 - psnr: 20.0741 - ssim_metric: 0.4369 - val_accuracy: 0.7342 - val_loss: 0.0087 - val_psnr: 20.6845 - val_ssim_metric: 0.4915
# Epoch 192/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.6600 - loss: 0.0118 - psnr: 19.4165 - ssim_metric: 0.3707 - val_accuracy: 0.7050 - val_loss: 0.0102 - val_psnr: 20.0600 - val_ssim_metric: 0.4585
# Epoch 193/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.6827 - loss: 0.0110 - psnr: 19.7150 - ssim_metric: 0.3907 - val_accuracy: 0.6846 - val_loss: 0.0116 - val_psnr: 19.5408 - val_ssim_metric: 0.4018
# Epoch 194/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.7181 - loss: 0.0104 - psnr: 20.2663 - ssim_metric: 0.4905 - val_accuracy: 0.7211 - val_loss: 0.0092 - val_psnr: 20.5813 - val_ssim_metric: 0.4794
# Epoch 195/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.7092 - loss: 0.0105 - psnr: 19.9860 - ssim_metric: 0.4383 - val_accuracy: 0.6848 - val_loss: 0.0136 - val_psnr: 19.6267 - val_ssim_metric: 0.4016
# Epoch 196/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.7276 - loss: 0.0095 - psnr: 20.3990 - ssim_metric: 0.4288 - val_accuracy: 0.6976 - val_loss: 0.0106 - val_psnr: 19.9244 - val_ssim_metric: 0.4188
# Epoch 197/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 119ms/step - accuracy: 0.7493 - loss: 0.0084 - psnr: 20.8873 - ssim_metric: 0.4819 - val_accuracy: 0.7018 - val_loss: 0.0105 - val_psnr: 19.8754 - val_ssim_metric: 0.4045
# Epoch 198/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - accuracy: 0.7503 - loss: 0.0087 - psnr: 20.8512 - ssim_metric: 0.4404 - val_accuracy: 0.6967 - val_loss: 0.0111 - val_psnr: 19.7590 - val_ssim_metric: 0.4204
# Epoch 199/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 116ms/step - accuracy: 0.7480 - loss: 0.0093 - psnr: 20.8478 - ssim_metric: 0.4515 - val_accuracy: 0.7385 - val_loss: 0.0089 - val_psnr: 20.6277 - val_ssim_metric: 0.4986
# Epoch 200/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - accuracy: 0.6829 - loss: 0.0112 - psnr: 19.6422 - ssim_metric: 0.3888 - val_accuracy: 0.7752 - val_loss: 0.0078 - val_psnr: 21.1791 - val_ssim_metric: 0.4920
# Epoch 201/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - accuracy: 0.7160 - loss: 0.0098 - psnr: 20.2049 - ssim_metric: 0.4157 - val_accuracy: 0.6445 - val_loss: 0.0135 - val_psnr: 18.9332 - val_ssim_metric: 0.4091
# Epoch 202/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.7517 - loss: 0.0086 - psnr: 20.8277 - ssim_metric: 0.5261 - val_accuracy: 0.7057 - val_loss: 0.0099 - val_psnr: 20.2628 - val_ssim_metric: 0.4745
# Epoch 203/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.7202 - loss: 0.0101 - psnr: 20.1333 - ssim_metric: 0.4474 - val_accuracy: 0.6913 - val_loss: 0.0108 - val_psnr: 19.8063 - val_ssim_metric: 0.4209
# Epoch 204/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.7019 - loss: 0.0103 - psnr: 20.0450 - ssim_metric: 0.4291 - val_accuracy: 0.6856 - val_loss: 0.0118 - val_psnr: 19.6755 - val_ssim_metric: 0.4286
# Epoch 205/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.7464 - loss: 0.0088 - psnr: 20.7915 - ssim_metric: 0.5066 - val_accuracy: 0.7100 - val_loss: 0.0101 - val_psnr: 20.0720 - val_ssim_metric: 0.4316
# Epoch 206/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 116ms/step - accuracy: 0.7587 - loss: 0.0085 - psnr: 20.8827 - ssim_metric: 0.4472 - val_accuracy: 0.7277 - val_loss: 0.0092 - val_psnr: 20.4195 - val_ssim_metric: 0.4346
# Epoch 207/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - accuracy: 0.7430 - loss: 0.0091 - psnr: 20.8374 - ssim_metric: 0.4532 - val_accuracy: 0.8058 - val_loss: 0.0070 - val_psnr: 21.7690 - val_ssim_metric: 0.5427
# Epoch 208/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 118ms/step - accuracy: 0.7087 - loss: 0.0102 - psnr: 20.0873 - ssim_metric: 0.4139 - val_accuracy: 0.7958 - val_loss: 0.0072 - val_psnr: 21.6071 - val_ssim_metric: 0.4994
# Epoch 209/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.7409 - loss: 0.0090 - psnr: 20.5783 - ssim_metric: 0.4325 - val_accuracy: 0.7499 - val_loss: 0.0089 - val_psnr: 20.6221 - val_ssim_metric: 0.4319
# Epoch 210/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.8058 - loss: 0.0069 - psnr: 21.8090 - ssim_metric: 0.5308 - val_accuracy: 0.7837 - val_loss: 0.0075 - val_psnr: 21.4705 - val_ssim_metric: 0.5077
# Epoch 211/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.7776 - loss: 0.0077 - psnr: 21.3082 - ssim_metric: 0.4749 - val_accuracy: 0.7591 - val_loss: 0.0085 - val_psnr: 20.8598 - val_ssim_metric: 0.4534
# Epoch 212/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.7756 - loss: 0.0080 - psnr: 21.1631 - ssim_metric: 0.4565 - val_accuracy: 0.7566 - val_loss: 0.0085 - val_psnr: 20.8599 - val_ssim_metric: 0.4584
# Epoch 213/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.7966 - loss: 0.0070 - psnr: 21.7041 - ssim_metric: 0.5232 - val_accuracy: 0.7150 - val_loss: 0.0098 - val_psnr: 20.3104 - val_ssim_metric: 0.4480
# Epoch 214/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - accuracy: 0.7684 - loss: 0.0079 - psnr: 21.2331 - ssim_metric: 0.4623 - val_accuracy: 0.7478 - val_loss: 0.0092 - val_psnr: 20.5251 - val_ssim_metric: 0.4577
# Epoch 215/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - accuracy: 0.7871 - loss: 0.0077 - psnr: 21.5424 - ssim_metric: 0.4804 - val_accuracy: 0.8476 - val_loss: 0.0056 - val_psnr: 22.6040 - val_ssim_metric: 0.5613
# Epoch 216/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - accuracy: 0.7154 - loss: 0.0111 - psnr: 20.0922 - ssim_metric: 0.4194 - val_accuracy: 0.6761 - val_loss: 0.0157 - val_psnr: 19.5509 - val_ssim_metric: 0.4613
# Epoch 217/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 123ms/step - accuracy: 0.7241 - loss: 0.0090 - psnr: 20.5152 - ssim_metric: 0.4301 - val_accuracy: 0.7673 - val_loss: 0.0085 - val_psnr: 20.9795 - val_ssim_metric: 0.4685
# Epoch 218/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.8307 - loss: 0.0062 - psnr: 22.2548 - ssim_metric: 0.5487 - val_accuracy: 0.8288 - val_loss: 0.0061 - val_psnr: 22.3146 - val_ssim_metric: 0.5348
# Epoch 219/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - accuracy: 0.7988 - loss: 0.0071 - psnr: 21.6363 - ssim_metric: 0.4930 - val_accuracy: 0.7532 - val_loss: 0.0087 - val_psnr: 20.8533 - val_ssim_metric: 0.4589
# Epoch 220/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.7995 - loss: 0.0071 - psnr: 21.7432 - ssim_metric: 0.4785 - val_accuracy: 0.7868 - val_loss: 0.0077 - val_psnr: 21.3425 - val_ssim_metric: 0.4759
# Epoch 221/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.8366 - loss: 0.0059 - psnr: 22.4791 - ssim_metric: 0.5397 - val_accuracy: 0.7580 - val_loss: 0.0082 - val_psnr: 20.9750 - val_ssim_metric: 0.4591
# Epoch 222/1500
# ...
# Epoch 1431/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 115ms/step - accuracy: 0.9901 - loss: 0.0010 - psnr: 30.3074 - ssim_metric: 0.8570 - val_accuracy: 0.9918 - val_loss: 0.0010 - val_psnr: 30.2085 - val_ssim_metric: 0.8692
# Epoch 1432/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - accuracy: 0.9886 - loss: 0.0011 - psnr: 29.9877 - ssim_metric: 0.8623 - val_accuracy: 0.8999 - val_loss: 0.0086 - val_psnr: 27.2362 - val_ssim_metric: 0.7520
# Epoch 1433/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 129ms/step - accuracy: 0.8387 - loss: 0.0132 - psnr: 25.4913 - ssim_metric: 0.6806 - val_accuracy: 0.8881 - val_loss: 0.0083 - val_psnr: 26.8336 - val_ssim_metric: 0.7466
# Epoch 1434/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 130ms/step - accuracy: 0.9849 - loss: 0.0013 - psnr: 29.6423 - ssim_metric: 0.8419 - val_accuracy: 0.9848 - val_loss: 0.0013 - val_psnr: 28.9819 - val_ssim_metric: 0.8452
# Epoch 1435/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 149ms/step - accuracy: 0.9869 - loss: 0.0013 - psnr: 29.0327 - ssim_metric: 0.8396 - val_accuracy: 0.8809 - val_loss: 0.0085 - val_psnr: 26.2216 - val_ssim_metric: 0.7492
# Epoch 1436/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 112ms/step - accuracy: 0.8807 - loss: 0.0079 - psnr: 25.3786 - ssim_metric: 0.7373 - val_accuracy: 0.9933 - val_loss: 8.0493e-04 - val_psnr: 31.5116 - val_ssim_metric: 0.8743
# Epoch 1437/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - accuracy: 0.9904 - loss: 0.0010 - psnr: 30.3092 - ssim_metric: 0.8664 - val_accuracy: 0.9947 - val_loss: 8.8137e-04 - val_psnr: 30.6871 - val_ssim_metric: 0.8578
# Epoch 1438/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 112ms/step - accuracy: 0.9837 - loss: 0.0013 - psnr: 29.0141 - ssim_metric: 0.8419 - val_accuracy: 0.9733 - val_loss: 0.0017 - val_psnr: 27.9964 - val_ssim_metric: 0.8154
# Epoch 1439/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - accuracy: 0.8776 - loss: 0.0118 - psnr: 26.0815 - ssim_metric: 0.7420 - val_accuracy: 0.8942 - val_loss: 0.0115 - val_psnr: 27.2632 - val_ssim_metric: 0.7572
# Epoch 1440/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 116ms/step - accuracy: 0.9841 - loss: 0.0013 - psnr: 29.1338 - ssim_metric: 0.8523 - val_accuracy: 0.9875 - val_loss: 0.0012 - val_psnr: 29.1997 - val_ssim_metric: 0.8460
# Epoch 1441/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - accuracy: 0.9797 - loss: 0.0015 - psnr: 28.7201 - ssim_metric: 0.8349 - val_accuracy: 0.9681 - val_loss: 0.0017 - val_psnr: 28.9725 - val_ssim_metric: 0.8414
# Epoch 1442/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 117ms/step - accuracy: 0.9917 - loss: 9.7756e-04 - psnr: 30.4540 - ssim_metric: 0.8501 - val_accuracy: 0.9874 - val_loss: 0.0012 - val_psnr: 29.3805 - val_ssim_metric: 0.8597
# Epoch 1443/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 130ms/step - accuracy: 0.9893 - loss: 0.0012 - psnr: 29.5172 - ssim_metric: 0.8455 - val_accuracy: 0.9874 - val_loss: 0.0012 - val_psnr: 29.4629 - val_ssim_metric: 0.8500
# Epoch 1444/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 137ms/step - accuracy: 0.9774 - loss: 0.0015 - psnr: 28.3904 - ssim_metric: 0.8355 - val_accuracy: 0.9952 - val_loss: 7.3641e-04 - val_psnr: 31.8263 - val_ssim_metric: 0.8904
# Epoch 1445/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - accuracy: 0.9932 - loss: 9.0432e-04 - psnr: 30.7599 - ssim_metric: 0.8701 - val_accuracy: 0.9917 - val_loss: 0.0010 - val_psnr: 30.0403 - val_ssim_metric: 0.8530
# Epoch 1446/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 115ms/step - accuracy: 0.9900 - loss: 0.0011 - psnr: 29.5978 - ssim_metric: 0.8511 - val_accuracy: 0.9816 - val_loss: 0.0014 - val_psnr: 28.6041 - val_ssim_metric: 0.8440
# Epoch 1447/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 117ms/step - accuracy: 0.9805 - loss: 0.0013 - psnr: 29.4156 - ssim_metric: 0.8356 - val_accuracy: 0.9935 - val_loss: 9.2246e-04 - val_psnr: 30.6745 - val_ssim_metric: 0.8760
# Epoch 1448/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - accuracy: 0.9894 - loss: 0.0011 - psnr: 29.9946 - ssim_metric: 0.8614 - val_accuracy: 0.9905 - val_loss: 0.0011 - val_psnr: 29.6415 - val_ssim_metric: 0.8549
# Epoch 1449/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 113ms/step - accuracy: 0.9850 - loss: 0.0013 - psnr: 29.2260 - ssim_metric: 0.8457 - val_accuracy: 0.9875 - val_loss: 0.0011 - val_psnr: 30.4153 - val_ssim_metric: 0.8592
# Epoch 1450/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - accuracy: 0.9933 - loss: 8.3964e-04 - psnr: 31.2506 - ssim_metric: 0.8601 - val_accuracy: 0.9894 - val_loss: 0.0011 - val_psnr: 29.6754 - val_ssim_metric: 0.8653
# Epoch 1451/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - accuracy: 0.9917 - loss: 0.0010 - psnr: 29.9520 - ssim_metric: 0.8530 - val_accuracy: 0.9912 - val_loss: 0.0011 - val_psnr: 29.7558 - val_ssim_metric: 0.8601
# Epoch 1452/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - accuracy: 0.9093 - loss: 0.0056 - psnr: 26.7278 - ssim_metric: 0.7621 - val_accuracy: 0.9143 - val_loss: 0.0057 - val_psnr: 30.0086 - val_ssim_metric: 0.7945
# Epoch 1453/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 131ms/step - accuracy: 0.9949 - loss: 8.1544e-04 - psnr: 31.3286 - ssim_metric: 0.8777 - val_accuracy: 0.9944 - val_loss: 8.5718e-04 - val_psnr: 30.8173 - val_ssim_metric: 0.8643
# Epoch 1454/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 134ms/step - accuracy: 0.9236 - loss: 0.0071 - psnr: 27.8739 - ssim_metric: 0.7846 - val_accuracy: 0.8718 - val_loss: 0.0103 - val_psnr: 25.3046 - val_ssim_metric: 0.7207
# Epoch 1455/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 130ms/step - accuracy: 0.9842 - loss: 0.0013 - psnr: 29.3605 - ssim_metric: 0.8458 - val_accuracy: 0.8958 - val_loss: 0.0082 - val_psnr: 28.1825 - val_ssim_metric: 0.7694
# Epoch 1456/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 113ms/step - accuracy: 0.9376 - loss: 0.0050 - psnr: 29.0587 - ssim_metric: 0.8050 - val_accuracy: 0.9691 - val_loss: 0.0018 - val_psnr: 28.2268 - val_ssim_metric: 0.8394
# Epoch 1457/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - accuracy: 0.9808 - loss: 0.0014 - psnr: 28.7127 - ssim_metric: 0.8384 - val_accuracy: 0.9873 - val_loss: 0.0011 - val_psnr: 30.0326 - val_ssim_metric: 0.8549
# Epoch 1458/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - accuracy: 0.9121 - loss: 0.0091 - psnr: 28.2109 - ssim_metric: 0.7839 - val_accuracy: 0.8920 - val_loss: 0.0108 - val_psnr: 26.1718 - val_ssim_metric: 0.7691
# Epoch 1459/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 112ms/step - accuracy: 0.9721 - loss: 0.0017 - psnr: 28.2949 - ssim_metric: 0.8293 - val_accuracy: 0.9903 - val_loss: 0.0011 - val_psnr: 29.4908 - val_ssim_metric: 0.8606
# Epoch 1460/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 112ms/step - accuracy: 0.9804 - loss: 0.0014 - psnr: 28.5441 - ssim_metric: 0.8383 - val_accuracy: 0.9781 - val_loss: 0.0013 - val_psnr: 30.3698 - val_ssim_metric: 0.8649
# Epoch 1461/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - accuracy: 0.9933 - loss: 8.8047e-04 - psnr: 31.0128 - ssim_metric: 0.8730 - val_accuracy: 0.9171 - val_loss: 0.0084 - val_psnr: 28.3095 - val_ssim_metric: 0.7792
# Epoch 1462/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - accuracy: 0.9186 - loss: 0.0077 - psnr: 26.9961 - ssim_metric: 0.7682 - val_accuracy: 0.9716 - val_loss: 0.0017 - val_psnr: 27.9302 - val_ssim_metric: 0.8237
# Epoch 1463/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 129ms/step - accuracy: 0.9843 - loss: 0.0012 - psnr: 29.5758 - ssim_metric: 0.8518 - val_accuracy: 0.9901 - val_loss: 0.0011 - val_psnr: 29.9765 - val_ssim_metric: 0.8602
# Epoch 1464/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 130ms/step - accuracy: 0.9909 - loss: 0.0010 - psnr: 30.2040 - ssim_metric: 0.8631 - val_accuracy: 0.9863 - val_loss: 0.0013 - val_psnr: 28.9829 - val_ssim_metric: 0.8534
# Epoch 1465/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step - accuracy: 0.9616 - loss: 0.0020 - psnr: 27.9545 - ssim_metric: 0.8280 - val_accuracy: 0.9007 - val_loss: 0.0072 - val_psnr: 27.4195 - val_ssim_metric: 0.7779
# Epoch 1466/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 118ms/step - accuracy: 0.9194 - loss: 0.0059 - psnr: 28.5123 - ssim_metric: 0.7839 - val_accuracy: 0.9880 - val_loss: 0.0012 - val_psnr: 29.4811 - val_ssim_metric: 0.8510
# Epoch 1467/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - accuracy: 0.9854 - loss: 0.0013 - psnr: 28.8754 - ssim_metric: 0.8419 - val_accuracy: 0.9911 - val_loss: 0.0011 - val_psnr: 29.7081 - val_ssim_metric: 0.8658
# Epoch 1468/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 113ms/step - accuracy: 0.9087 - loss: 0.0060 - psnr: 26.6920 - ssim_metric: 0.7607 - val_accuracy: 0.9172 - val_loss: 0.0048 - val_psnr: 29.3079 - val_ssim_metric: 0.7938
# Epoch 1469/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - accuracy: 0.9935 - loss: 8.9408e-04 - psnr: 30.8736 - ssim_metric: 0.8746 - val_accuracy: 0.9929 - val_loss: 9.5282e-04 - val_psnr: 30.4255 - val_ssim_metric: 0.8585
# Epoch 1470/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 113ms/step - accuracy: 0.9892 - loss: 0.0012 - psnr: 29.4137 - ssim_metric: 0.8497 - val_accuracy: 0.9766 - val_loss: 0.0015 - val_psnr: 28.2283 - val_ssim_metric: 0.8203
# Epoch 1471/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - accuracy: 0.8903 - loss: 0.0114 - psnr: 26.6285 - ssim_metric: 0.7529 - val_accuracy: 0.7973 - val_loss: 0.0182 - val_psnr: 24.7979 - val_ssim_metric: 0.6633
# Epoch 1472/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 140ms/step - accuracy: 0.9026 - loss: 0.0064 - psnr: 26.9931 - ssim_metric: 0.7716 - val_accuracy: 0.9809 - val_loss: 0.0016 - val_psnr: 28.0779 - val_ssim_metric: 0.8351
# Epoch 1473/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - accuracy: 0.9770 - loss: 0.0016 - psnr: 28.1124 - ssim_metric: 0.8298 - val_accuracy: 0.9738 - val_loss: 0.0016 - val_psnr: 28.8948 - val_ssim_metric: 0.8475
# Epoch 1474/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 135ms/step - accuracy: 0.9914 - loss: 0.0010 - psnr: 30.3156 - ssim_metric: 0.8498 - val_accuracy: 0.9789 - val_loss: 0.0014 - val_psnr: 29.1297 - val_ssim_metric: 0.8506
# Epoch 1475/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 120ms/step - accuracy: 0.9858 - loss: 0.0013 - psnr: 29.0981 - ssim_metric: 0.8438 - val_accuracy: 0.9899 - val_loss: 0.0011 - val_psnr: 29.5676 - val_ssim_metric: 0.8567
# Epoch 1476/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 115ms/step - accuracy: 0.9797 - loss: 0.0015 - psnr: 28.5605 - ssim_metric: 0.8354 - val_accuracy: 0.9938 - val_loss: 7.4951e-04 - val_psnr: 31.8759 - val_ssim_metric: 0.8857
# Epoch 1477/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - accuracy: 0.9923 - loss: 8.6753e-04 - psnr: 31.2823 - ssim_metric: 0.8779 - val_accuracy: 0.9934 - val_loss: 9.6050e-04 - val_psnr: 30.3140 - val_ssim_metric: 0.8597
# Epoch 1478/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 116ms/step - accuracy: 0.9887 - loss: 0.0012 - psnr: 29.3009 - ssim_metric: 0.8447 - val_accuracy: 0.9787 - val_loss: 0.0015 - val_psnr: 28.5671 - val_ssim_metric: 0.8304
# Epoch 1479/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - accuracy: 0.9863 - loss: 0.0012 - psnr: 29.6545 - ssim_metric: 0.8539 - val_accuracy: 0.9936 - val_loss: 8.8409e-04 - val_psnr: 30.8825 - val_ssim_metric: 0.8717
# Epoch 1480/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - accuracy: 0.9908 - loss: 0.0010 - psnr: 30.1885 - ssim_metric: 0.8644 - val_accuracy: 0.9885 - val_loss: 0.0012 - val_psnr: 29.4405 - val_ssim_metric: 0.8565
# Epoch 1481/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 120ms/step - accuracy: 0.9876 - loss: 0.0012 - psnr: 29.4784 - ssim_metric: 0.8478 - val_accuracy: 0.9895 - val_loss: 0.0011 - val_psnr: 30.2043 - val_ssim_metric: 0.8618
# Epoch 1482/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 120ms/step - accuracy: 0.9916 - loss: 9.4266e-04 - psnr: 30.8871 - ssim_metric: 0.8602 - val_accuracy: 0.9904 - val_loss: 0.0011 - val_psnr: 29.8078 - val_ssim_metric: 0.8656
# Epoch 1483/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - accuracy: 0.9875 - loss: 0.0012 - psnr: 29.3627 - ssim_metric: 0.8492 - val_accuracy: 0.9908 - val_loss: 0.0011 - val_psnr: 29.8410 - val_ssim_metric: 0.8592
# Epoch 1484/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 129ms/step - accuracy: 0.9857 - loss: 0.0012 - psnr: 29.2001 - ssim_metric: 0.8492 - val_accuracy: 0.9956 - val_loss: 7.4051e-04 - val_psnr: 31.6991 - val_ssim_metric: 0.8884
# Epoch 1485/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 119ms/step - accuracy: 0.9948 - loss: 7.7585e-04 - psnr: 31.6542 - ssim_metric: 0.8826 - val_accuracy: 0.9928 - val_loss: 0.0010 - val_psnr: 30.0868 - val_ssim_metric: 0.8610
# Epoch 1486/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - accuracy: 0.9900 - loss: 0.0012 - psnr: 29.4050 - ssim_metric: 0.8488 - val_accuracy: 0.9808 - val_loss: 0.0014 - val_psnr: 28.7503 - val_ssim_metric: 0.8376
# Epoch 1487/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 113ms/step - accuracy: 0.9898 - loss: 0.0010 - psnr: 30.2177 - ssim_metric: 0.8602 - val_accuracy: 0.9940 - val_loss: 8.8351e-04 - val_psnr: 30.8196 - val_ssim_metric: 0.8727
# Epoch 1488/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - accuracy: 0.9908 - loss: 0.0010 - psnr: 30.3055 - ssim_metric: 0.8684 - val_accuracy: 0.9896 - val_loss: 0.0012 - val_psnr: 29.4135 - val_ssim_metric: 0.8568
# Epoch 1489/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 112ms/step - accuracy: 0.9863 - loss: 0.0012 - psnr: 29.2503 - ssim_metric: 0.8463 - val_accuracy: 0.9053 - val_loss: 0.0102 - val_psnr: 27.3537 - val_ssim_metric: 0.7939
# Epoch 1490/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - accuracy: 0.9204 - loss: 0.0088 - psnr: 28.5781 - ssim_metric: 0.8005 - val_accuracy: 0.9828 - val_loss: 0.0015 - val_psnr: 28.4475 - val_ssim_metric: 0.8571
# Epoch 1491/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 118ms/step - accuracy: 0.9841 - loss: 0.0014 - psnr: 28.8619 - ssim_metric: 0.8457 - val_accuracy: 0.9924 - val_loss: 0.0010 - val_psnr: 29.8740 - val_ssim_metric: 0.8627
# Epoch 1492/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 133ms/step - accuracy: 0.9825 - loss: 0.0014 - psnr: 28.7555 - ssim_metric: 0.8434 - val_accuracy: 0.9944 - val_loss: 8.1630e-04 - val_psnr: 31.3724 - val_ssim_metric: 0.8861
# Epoch 1493/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 134ms/step - accuracy: 0.9768 - loss: 0.0014 - psnr: 29.6162 - ssim_metric: 0.8683 - val_accuracy: 0.8964 - val_loss: 0.0090 - val_psnr: 27.5772 - val_ssim_metric: 0.7535
# Epoch 1494/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 140ms/step - accuracy: 0.9070 - loss: 0.0080 - psnr: 27.6201 - ssim_metric: 0.7679 - val_accuracy: 0.8024 - val_loss: 0.0162 - val_psnr: 24.1288 - val_ssim_metric: 0.6562
# Epoch 1495/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 119ms/step - accuracy: 0.7356 - loss: 0.0225 - psnr: 21.9243 - ssim_metric: 0.5876 - val_accuracy: 0.8484 - val_loss: 0.0125 - val_psnr: 24.2226 - val_ssim_metric: 0.7251
# Epoch 1496/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - accuracy: 0.9602 - loss: 0.0020 - psnr: 27.2568 - ssim_metric: 0.8338 - val_accuracy: 0.9800 - val_loss: 0.0015 - val_psnr: 28.1789 - val_ssim_metric: 0.8375
# Epoch 1497/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - accuracy: 0.9773 - loss: 0.0016 - psnr: 28.2956 - ssim_metric: 0.8298 - val_accuracy: 0.9630 - val_loss: 0.0020 - val_psnr: 28.3444 - val_ssim_metric: 0.8308
# Epoch 1498/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - accuracy: 0.9862 - loss: 0.0013 - psnr: 29.3712 - ssim_metric: 0.8374 - val_accuracy: 0.9831 - val_loss: 0.0015 - val_psnr: 28.4940 - val_ssim_metric: 0.8493
# Epoch 1499/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - accuracy: 0.9841 - loss: 0.0014 - psnr: 28.7343 - ssim_metric: 0.8367 - val_accuracy: 0.9906 - val_loss: 0.0011 - val_psnr: 29.6511 - val_ssim_metric: 0.8570
# Epoch 1500/1500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - accuracy: 0.9728 - loss: 0.0017 - psnr: 28.1776 - ssim_metric: 0.8323 - val_accuracy: 0.9956 - val_loss: 7.4174e-04 - val_psnr: 31.6814 - val_ssim_metric: 0.8797
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.9862 - loss: 0.0013 - psnr: 28.8308 - ssim_metric: 0.8489
# Test Loss: 0.0013
# Test PSNR: 29.0366
# Test SSIM: 0.8593
# Test Accuracy: 0.9872
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step
# PSNR: 29.3352
# SSIM: 0.7794

# %%
# Manually specify the image file
selected_file = '0099.tif'  # Replace this with your desired image name
hazy_path = os.path.join(hazy_dir, selected_file)
clear_path = os.path.join(clear_dir, selected_file)  # Assuming clear images have the same filename

# Load and preprocess the images
def load_and_preprocess(image_path):
    img = load_img(image_path, target_size=(128, 128))
    img_array = img_to_array(img) / 255.0
    return img_array

hazy_image = load_and_preprocess(hazy_path)
clear_image = load_and_preprocess(clear_path)

# Dehaze the image
dehazed_image = model.predict(np.expand_dims(hazy_image, axis=0))[0]

# Calculate PSNR and SSIM
psnr = tf.image.psnr(clear_image, dehazed_image, max_val=1.0)
ssim = tf.image.ssim(clear_image, dehazed_image, max_val=1.0)

print(f"PSNR: {psnr.numpy():.4f}")
print(f"SSIM: {ssim.numpy():.4f}")

# Display images
plt.figure(figsize=(15, 5))
plt.subplot(131)
plt.imshow(hazy_image)
plt.title('Hazy Image')
plt.axis('off')

plt.subplot(132)
plt.imshow(dehazed_image)
plt.title('Dehazed Image')
plt.axis('off')

plt.subplot(133)
plt.imshow(clear_image)
plt.title('Clear Image')
plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# PSNR: 26.9829
# SSIM: 0.8293
